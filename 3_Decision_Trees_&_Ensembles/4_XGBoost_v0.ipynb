# %% [markdown]
# # 1. Import Libraries & Dataset

# %%
#!pip install scikit-learn
#!pip install matplotlib
#!pip install seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.tree import DecisionTreeClassifier, export_text
from sklearn.metrics import roc_auc_score, confusion_matrix, accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from matplotlib.colors import ListedColormap

# %%
# first try was with AU columns only --> then we added pose & gaze as well for better results

# # load dataset

# dataset_by_mean = pd.read_pickle('dolos_aggr_mean.pkl')
# dataset_by_mean

# dataset_by_max = pd.read_pickle('dolos_aggr_max.pkl')
# dataset_by_max

# dataset_by_std = pd.read_pickle('dolos_aggr_std.pkl')
# dataset_by_std

# %%
# load dataset

dataset_by_mean = pd.read_pickle('dolos_aggr_mean_v2.pkl')
dataset_by_mean

dataset_by_max = pd.read_pickle('dolos_aggr_max_v2.pkl')
dataset_by_max

dataset_by_std = pd.read_pickle('dolos_aggr_std_v2.pkl')
dataset_by_std
# Out:
#                   video_id    AU01_r    AU02_r    AU04_r    AU05_r    AU06_r  \
# 0      AN_WILTY_EP15_lie10  0.131243  0.085327  0.562402  0.033261  0.132124
# 1      AN_WILTY_EP15_lie11  0.314456  0.219906  0.000000  0.130074  0.005639
# 2      AN_WILTY_EP15_lie12  0.095647  0.070883  0.217000  0.079565  0.381883
# 3      AN_WILTY_EP15_lie13  0.095652  0.076767  0.000000  0.048791  0.109656
# 4      AN_WILTY_EP15_lie14  0.385574  0.348092  0.000000  0.113538  0.440128
# ...                    ...       ...       ...       ...       ...       ...
# 1464  YW_WILTY_EP70_truth5  0.147764  0.145458  0.101270  0.152342  0.292310
# 1465  YW_WILTY_EP70_truth6  0.527518  0.200851  0.521999  0.367288  0.429061
# 1466  YW_WILTY_EP70_truth7  0.436879  0.281196  0.361892  0.057731  0.114382
# 1467  YW_WILTY_EP70_truth8  0.301876  0.182715  0.172107  0.656657  0.452309
# 1468  YW_WILTY_EP70_truth9  0.203580  0.098266  0.283895  0.058454  0.242502
#
#         AU07_r    AU09_r    AU10_r    AU12_r    AU14_r    AU15_r    AU17_r  \
# 0     0.181448  0.057571  0.446373  0.352630  0.328930  0.250137  0.613029
# 1     0.000000  0.095572  0.297845  0.164786  0.574241  0.128785  0.315298
# 2     0.461531  0.253215  0.538801  0.348212  0.470164  0.218579  0.369704
# 3     0.129917  0.066048  0.419778  0.430428  0.564710  0.156834  0.403426
# 4     0.313956  0.082497  0.566972  0.704785  0.606506  0.211128  0.458031
# ...        ...       ...       ...       ...       ...       ...       ...
# 1464  0.311208  0.064355  0.373886  0.475253  0.197343  0.117519  0.375382
# 1465  0.612170  0.167712  0.636275  0.572024  0.434525  0.216840  0.814998
# 1466  0.298365  0.099114  0.140731  0.228547  0.000000  0.119782  0.231936
# 1467  0.531807  0.094904  0.408353  0.513274  0.409628  0.241323  0.342012
# 1468  0.225606  0.181472  0.425206  0.377515  0.068358  0.207214  0.334450
#
#         AU20_r    AU23_r    AU25_r    AU26_r    AU45_r  label
# 0     0.202917  0.883192  0.484299  0.255969  0.541820    lie
# 1     0.304688  0.075921  0.738018  0.412409  0.517922    lie
# 2     0.104691  0.131936  0.748007  0.199011  0.273745    lie
# 3     0.261671  0.154435  0.747965  0.170817  0.218009    lie
# 4     0.145545  0.773404  0.500637  0.358693  0.505588    lie
# ...        ...       ...       ...       ...       ...    ...
# 1464  0.117984  0.222157  0.337628  0.295916  0.133761  truth
# 1465  0.204555  0.824962  0.778455  0.436423  0.167658  truth
# 1466  0.119833  0.336092  0.227178  0.328183  0.138739  truth
# 1467  0.153941  0.362793  0.467196  0.542345  0.173500  truth
# 1468  0.121331  0.155389  0.383105  0.437311  0.113670  truth
#
# [1469 rows x 19 columns]

# %% [markdown]
# # 2. Decision Tree Analysis

# %% [markdown]
# ## Mean

# %%
dataset = dataset_by_mean

# %%
# dataset_by_mean.min()
# dataset_by_mean.max()

# %%
# prepare X and y

X_mean = dataset.iloc[:, 1:-1].values

# map 'lie' to 0 & 'truth' to 1
y_mean = dataset.iloc[:, -1].map({'lie': 0, 'truth': 1}).values

# %%
# splitting the dataset into the training set and test set

X_train_mean, X_test_mean, y_train_mean, y_test_mean = train_test_split(X_mean, y_mean, test_size = 0.20)

# %%
# train the decision tree model on the training set

classifier_entropy_mean = DecisionTreeClassifier(criterion = 'entropy', max_depth = 4, min_samples_split = 4, random_state = 0)
classifier_entropy_mean.fit(X_train_mean, y_train_mean)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4, min_samples_split=4,
#                        random_state=0)

# %%
# predicting the Test set results

y_pred_mean = classifier_entropy_mean.predict(X_test_mean)
#print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

# %% [markdown]
# ## Max

# %%
dataset = dataset_by_max

# %%
dataset_by_max.min()
dataset_by_max.max()
# Out:
# video_id    YW_WILTY_EP70_truth9
# AU01_r                       5.0
# AU02_r                       5.0
# AU04_r                      3.89
# AU05_r                      3.46
# AU06_r                      3.52
# AU07_r                       4.6
# AU09_r                      2.77
# AU10_r                      4.63
# AU12_r                      4.07
# AU14_r                      4.36
# AU15_r                       5.0
# AU17_r                       5.0
# AU20_r                      4.29
# AU23_r                       5.0
# AU25_r                      4.63
# AU26_r                       5.0
# AU45_r                      3.85
# label                      truth
# dtype: object

# %%
# prepare X and y

X_max = dataset.iloc[:, 1:-1].values

# map 'lie' to 0 & 'truth' to 1
y_max = dataset.iloc[:, -1].map({'lie': 0, 'truth': 1}).values

# %%
# splitting the dataset into the training set and test set

X_train_max, X_test_max, y_train_max, y_test_max = train_test_split(X_max, y_max, test_size = 0.20)

# %%
# train the decision tree model on the training set

classifier_entropy_max = DecisionTreeClassifier(criterion = 'entropy', max_depth = 4, min_samples_split = 4, random_state = 0)
classifier_entropy_max.fit(X_train_max, y_train_max)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4, min_samples_split=4,
#                        random_state=0)

# %%
# predicting the Test set results

y_pred_max = classifier_entropy_max.predict(X_test_max)
#print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

# %% [markdown]
# ## STD

# %%
dataset = dataset_by_std

# %%
# dataset_by_std.min()
# dataset_by_std.max()

# %%
# prepare X and y

X_std = dataset.iloc[:, 1:-1].values

# map 'lie' to 0 & 'truth' to 1
y_std = dataset.iloc[:, -1].map({'lie': 0, 'truth': 1}).values

# %%
# splitting the dataset into the training set and test set

X_train_std, X_test_std, y_train_std, y_test_std = train_test_split(X_std, y_std, test_size = 0.20)

# %%
# train the decision tree model on the training set

classifier_entropy_std = DecisionTreeClassifier(criterion = 'entropy', max_depth = 4, min_samples_split = 4, random_state = 0)
classifier_entropy_std.fit(X_train_std, y_train_std)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4, min_samples_split=4,
#                        random_state=0)

# %%
# predicting the Test set results

y_pred_std = classifier_entropy_std.predict(X_test_std)
#print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

# %% [markdown]
# # 3. Metrics

# %% [markdown]
# ## Mean

# %%
# confusion matrix

cm_mean = confusion_matrix(y_test_mean, y_pred_mean)
print(cm_mean)
accuracy_mean = accuracy_score(y_test_mean, y_pred_mean)
print("Accuracy: %.2f%%" % (accuracy_mean * 100.0))
# Out:
# [[113  45]
#  [ 78  58]]
# Accuracy: 58.16%

# %%
# predictions & AUC

p_mean = classifier_entropy_mean.predict_proba(X_test_mean)[:, 1]
auc_mean = roc_auc_score(y_mean, p_mean)

print("Decision Tree AUC:", auc_mean)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[94], line 4
#       1 # predictions & AUC
#       3 p_mean = classifier_entropy_mean.predict_proba(X_test_mean)[:, 1]
# ----> 4 auc_mean = roc_auc_score(y_mean, p_mean)
#       6 print("Decision Tree AUC:", auc_mean)
#
# File ~/.conda/envs/master_env/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~/.conda/envs/master_env/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:686, in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
#     684     labels = np.unique(y_true)
#     685     y_true = label_binarize(y_true, classes=labels)[:, 0]
# --> 686     return _average_binary_score(
#     687         partial(_binary_roc_auc_score, max_fpr=max_fpr),
#     688         y_true,
#     689         y_score,
#     690         average,
#     691         sample_weight=sample_weight,
#     692     )
#     693 else:  # multilabel-indicator
#     694     return _average_binary_score(
#     695         partial(_binary_roc_auc_score, max_fpr=max_fpr),
#     696         y_true,
#    (...)
#     699         sample_weight=sample_weight,
#     700     )
#
# File ~/.conda/envs/master_env/lib/python3.10/site-packages/sklearn/metrics/_base.py:69, in _average_binary_score(binary_metric, y_true, y_score, average, sample_weight)
#      66     raise ValueError("{0} format is not supported".format(y_type))
#      68 if y_type == "binary":
# ---> 69     return binary_metric(y_true, y_score, sample_weight=sample_weight)
#      71 check_consistent_length(y_true, y_score, sample_weight)
#      72 y_true = check_array(y_true)
#
# File ~/.conda/envs/master_env/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:433, in _binary_roc_auc_score(y_true, y_score, sample_weight, max_fpr)
#     424     warnings.warn(
#     425         (
#     426             "Only one class is present in y_true. ROC AUC score "
#    (...)
#     429         UndefinedMetricWarning,
#     430     )
#     431     return np.nan
# --> 433 fpr, tpr, _ = roc_curve(y_true, y_score, sample_weight=sample_weight)
#     434 if max_fpr is None or max_fpr == 1:
#     435     return auc(fpr, tpr)
#
# File ~/.conda/envs/master_env/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:191, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     189 global_skip_validation = get_config()["skip_parameter_validation"]
#     190 if global_skip_validation:
# --> 191     return func(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
#
# File ~/.conda/envs/master_env/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1163, in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#    1059 @validate_params(
#    1060     {
#    1061         "y_true": ["array-like"],
#    (...)
#    1070     y_true, y_score, *, pos_label=None, sample_weight=None, drop_intermediate=True
#    1071 ):
#    1072     """Compute Receiver operating characteristic (ROC).
#    1073
#    1074     Note: this implementation is restricted to the binary classification task.
#    (...)
#    1161     array([ inf, 0.8 , 0.4 , 0.35, 0.1 ])
#    1162     """
# -> 1163     fps, tps, thresholds = _binary_clf_curve(
#    1164         y_true, y_score, pos_label=pos_label, sample_weight=sample_weight
#    1165     )
#    1167     # Attempt to drop thresholds corresponding to points in between and
#    1168     # collinear with other points. These are always suboptimal and do not
#    1169     # appear on a plotted ROC curve (and thus do not affect the AUC).
#    (...)
#    1174     # but does not drop more complicated cases like fps = [1, 3, 7],
#    1175     # tps = [1, 2, 4]; there is no harm in keeping too many thresholds.
#    1176     if drop_intermediate and len(fps) > 2:
#
# File ~/.conda/envs/master_env/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:865, in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     862 if not (y_type == "binary" or (y_type == "multiclass" and pos_label is not None)):
#     863     raise ValueError("{0} format is not supported".format(y_type))
# --> 865 check_consistent_length(y_true, y_score, sample_weight)
#     866 y_true = column_or_1d(y_true)
#     867 y_score = column_or_1d(y_score)
#
# File ~/.conda/envs/master_env/lib/python3.10/site-packages/sklearn/utils/validation.py:473, in check_consistent_length(*arrays)
#     471 lengths = [_num_samples(X) for X in arrays if X is not None]
#     472 if len(set(lengths)) > 1:
# --> 473     raise ValueError(
#     474         "Found input variables with inconsistent numbers of samples: %r"
#     475         % [int(l) for l in lengths]
#     476     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [1469, 294]

# %% [markdown]
# ## Max

# %%
# confusion matrix

cm_max = confusion_matrix(y_test_max, y_pred_max)
print(cm_max)
accuracy_max = accuracy_score(y_test_max, y_pred_max)
print("Accuracy: %.2f%%" % (accuracy_max * 100.0))
# Out:
# [[134  31]
#  [ 74  55]]
# Accuracy: 64.29%

# %%
# predictions & AUC

p_max = classifier_entropy_max.predict_proba(X_test_max)[:, 1]
auc_max = roc_auc_score(y_max, p_max)

print("Decision Tree AUC:", auc_max)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[92], line 4
#       1 # predictions & AUC
#       3 p_max = classifier_entropy_max.predict_proba(X_test_max)[:, 1]
# ----> 4 auc_max = roc_auc_score(y_max, p_max)
#       6 print("Decision Tree AUC:", auc_max)
#
# File ~/.conda/envs/master_env/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~/.conda/envs/master_env/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:686, in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
#     684     labels = np.unique(y_true)
#     685     y_true = label_binarize(y_true, classes=labels)[:, 0]
# --> 686     return _average_binary_score(
#     687         partial(_binary_roc_auc_score, max_fpr=max_fpr),
#     688         y_true,
#     689         y_score,
#     690         average,
#     691         sample_weight=sample_weight,
#     692     )
#     693 else:  # multilabel-indicator
#     694     return _average_binary_score(
#     695         partial(_binary_roc_auc_score, max_fpr=max_fpr),
#     696         y_true,
#    (...)
#     699         sample_weight=sample_weight,
#     700     )
#
# File ~/.conda/envs/master_env/lib/python3.10/site-packages/sklearn/metrics/_base.py:69, in _average_binary_score(binary_metric, y_true, y_score, average, sample_weight)
#      66     raise ValueError("{0} format is not supported".format(y_type))
#      68 if y_type == "binary":
# ---> 69     return binary_metric(y_true, y_score, sample_weight=sample_weight)
#      71 check_consistent_length(y_true, y_score, sample_weight)
#      72 y_true = check_array(y_true)
#
# File ~/.conda/envs/master_env/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:433, in _binary_roc_auc_score(y_true, y_score, sample_weight, max_fpr)
#     424     warnings.warn(
#     425         (
#     426             "Only one class is present in y_true. ROC AUC score "
#    (...)
#     429         UndefinedMetricWarning,
#     430     )
#     431     return np.nan
# --> 433 fpr, tpr, _ = roc_curve(y_true, y_score, sample_weight=sample_weight)
#     434 if max_fpr is None or max_fpr == 1:
#     435     return auc(fpr, tpr)
#
# File ~/.conda/envs/master_env/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:191, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     189 global_skip_validation = get_config()["skip_parameter_validation"]
#     190 if global_skip_validation:
# --> 191     return func(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
#
# File ~/.conda/envs/master_env/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1163, in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#    1059 @validate_params(
#    1060     {
#    1061         "y_true": ["array-like"],
#    (...)
#    1070     y_true, y_score, *, pos_label=None, sample_weight=None, drop_intermediate=True
#    1071 ):
#    1072     """Compute Receiver operating characteristic (ROC).
#    1073
#    1074     Note: this implementation is restricted to the binary classification task.
#    (...)
#    1161     array([ inf, 0.8 , 0.4 , 0.35, 0.1 ])
#    1162     """
# -> 1163     fps, tps, thresholds = _binary_clf_curve(
#    1164         y_true, y_score, pos_label=pos_label, sample_weight=sample_weight
#    1165     )
#    1167     # Attempt to drop thresholds corresponding to points in between and
#    1168     # collinear with other points. These are always suboptimal and do not
#    1169     # appear on a plotted ROC curve (and thus do not affect the AUC).
#    (...)
#    1174     # but does not drop more complicated cases like fps = [1, 3, 7],
#    1175     # tps = [1, 2, 4]; there is no harm in keeping too many thresholds.
#    1176     if drop_intermediate and len(fps) > 2:
#
# File ~/.conda/envs/master_env/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:865, in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     862 if not (y_type == "binary" or (y_type == "multiclass" and pos_label is not None)):
#     863     raise ValueError("{0} format is not supported".format(y_type))
# --> 865 check_consistent_length(y_true, y_score, sample_weight)
#     866 y_true = column_or_1d(y_true)
#     867 y_score = column_or_1d(y_score)
#
# File ~/.conda/envs/master_env/lib/python3.10/site-packages/sklearn/utils/validation.py:473, in check_consistent_length(*arrays)
#     471 lengths = [_num_samples(X) for X in arrays if X is not None]
#     472 if len(set(lengths)) > 1:
# --> 473     raise ValueError(
#     474         "Found input variables with inconsistent numbers of samples: %r"
#     475         % [int(l) for l in lengths]
#     476     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [1469, 294]

# %% [markdown]
# ## STD

# %%
# confusion matrix

cm_std = confusion_matrix(y_test_std, y_pred_std)
print(cm_std)
accuracy_std = accuracy_score(y_test_std, y_pred_std)
print("Accuracy: %.2f%%" % (accuracy_std * 100.0))
# Out:
# [[142  12]
#  [127  13]]
# Accuracy: 52.72%

# %%
# predictions & AUC

p_std = classifier_entropy_std.predict_proba(X_test_std)[:, 1]
auc_std = roc_auc_score(y_std, p_std)

print("Decision Tree AUC:", auc_std)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[89], line 4
#       1 # predictions & AUC
#       3 p_std = classifier_entropy_std.predict_proba(X_test_std)[:, 1]
# ----> 4 auc_std = roc_auc_score(y_std, p_std)
#       6 print("Decision Tree AUC:", auc_std)
#
# File ~/.conda/envs/master_env/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~/.conda/envs/master_env/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:686, in roc_auc_score(y_true, y_score, average, sample_weight, max_fpr, multi_class, labels)
#     684     labels = np.unique(y_true)
#     685     y_true = label_binarize(y_true, classes=labels)[:, 0]
# --> 686     return _average_binary_score(
#     687         partial(_binary_roc_auc_score, max_fpr=max_fpr),
#     688         y_true,
#     689         y_score,
#     690         average,
#     691         sample_weight=sample_weight,
#     692     )
#     693 else:  # multilabel-indicator
#     694     return _average_binary_score(
#     695         partial(_binary_roc_auc_score, max_fpr=max_fpr),
#     696         y_true,
#    (...)
#     699         sample_weight=sample_weight,
#     700     )
#
# File ~/.conda/envs/master_env/lib/python3.10/site-packages/sklearn/metrics/_base.py:69, in _average_binary_score(binary_metric, y_true, y_score, average, sample_weight)
#      66     raise ValueError("{0} format is not supported".format(y_type))
#      68 if y_type == "binary":
# ---> 69     return binary_metric(y_true, y_score, sample_weight=sample_weight)
#      71 check_consistent_length(y_true, y_score, sample_weight)
#      72 y_true = check_array(y_true)
#
# File ~/.conda/envs/master_env/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:433, in _binary_roc_auc_score(y_true, y_score, sample_weight, max_fpr)
#     424     warnings.warn(
#     425         (
#     426             "Only one class is present in y_true. ROC AUC score "
#    (...)
#     429         UndefinedMetricWarning,
#     430     )
#     431     return np.nan
# --> 433 fpr, tpr, _ = roc_curve(y_true, y_score, sample_weight=sample_weight)
#     434 if max_fpr is None or max_fpr == 1:
#     435     return auc(fpr, tpr)
#
# File ~/.conda/envs/master_env/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:191, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     189 global_skip_validation = get_config()["skip_parameter_validation"]
#     190 if global_skip_validation:
# --> 191     return func(*args, **kwargs)
#     193 func_sig = signature(func)
#     195 # Map *args/**kwargs to the function signature
#
# File ~/.conda/envs/master_env/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:1163, in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#    1059 @validate_params(
#    1060     {
#    1061         "y_true": ["array-like"],
#    (...)
#    1070     y_true, y_score, *, pos_label=None, sample_weight=None, drop_intermediate=True
#    1071 ):
#    1072     """Compute Receiver operating characteristic (ROC).
#    1073
#    1074     Note: this implementation is restricted to the binary classification task.
#    (...)
#    1161     array([ inf, 0.8 , 0.4 , 0.35, 0.1 ])
#    1162     """
# -> 1163     fps, tps, thresholds = _binary_clf_curve(
#    1164         y_true, y_score, pos_label=pos_label, sample_weight=sample_weight
#    1165     )
#    1167     # Attempt to drop thresholds corresponding to points in between and
#    1168     # collinear with other points. These are always suboptimal and do not
#    1169     # appear on a plotted ROC curve (and thus do not affect the AUC).
#    (...)
#    1174     # but does not drop more complicated cases like fps = [1, 3, 7],
#    1175     # tps = [1, 2, 4]; there is no harm in keeping too many thresholds.
#    1176     if drop_intermediate and len(fps) > 2:
#
# File ~/.conda/envs/master_env/lib/python3.10/site-packages/sklearn/metrics/_ranking.py:865, in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     862 if not (y_type == "binary" or (y_type == "multiclass" and pos_label is not None)):
#     863     raise ValueError("{0} format is not supported".format(y_type))
# --> 865 check_consistent_length(y_true, y_score, sample_weight)
#     866 y_true = column_or_1d(y_true)
#     867 y_score = column_or_1d(y_score)
#
# File ~/.conda/envs/master_env/lib/python3.10/site-packages/sklearn/utils/validation.py:473, in check_consistent_length(*arrays)
#     471 lengths = [_num_samples(X) for X in arrays if X is not None]
#     472 if len(set(lengths)) > 1:
# --> 473     raise ValueError(
#     474         "Found input variables with inconsistent numbers of samples: %r"
#     475         % [int(l) for l in lengths]
#     476     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [1469, 294]
