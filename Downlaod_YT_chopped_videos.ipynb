# %% [markdown]
# # Import Libraries

# %%
# wipe out any existing ffmpeg python bindings
#!pip uninstall ffmpeg ffmpeg-python -y

# install ONLY the one the script needs
#!pip install ffmpeg-python

# %% [markdown]
# # Download videos

# %%
# %%time

# run the downloader using the timestamps file
# %run YT_video_downloader_v2.py YT_video_outputs dolos_timestamps.txt
# Out:
# 1 / 1678 UCPIBQDI0QM, DONE!
# 2 / 1678 UCPIBQDI0QM, DONE!
# 3 / 1678 UCPIBQDI0QM, DONE!
# 4 / 1678 UCPIBQDI0QM, DONE!
# 5 / 1678 UCPIBQDI0QM, DONE!
# 6 / 1678 UCPIBQDI0QM, DONE!
# 7 / 1678 UCPIBQDI0QM, DONE!
# 8 / 1678 UCPIBQDI0QM, DONE!
# 9 / 1678 UCPIBQDI0QM, DONE!
# 10 / 1678 UCPIBQDI0QM, DONE!
# 11 / 1678 UCPIBQDI0QM, DONE!
# 12 / 1678 UCPIBQDI0QM, DONE!
# 13 / 1678 UCPIBQDI0QM, DONE!
# 14 / 1678 UCPIBQDI0QM, DONE!
# 15 / 1678 UCPIBQDI0QM, DONE!
# 16 / 1678 UCPIBQDI0QM, DONE!
# 17 / 1678 UCPIBQDI0QM, DONE!
# 18 / 1678 UCPIBQDI0QM, DONE!
# 19 / 1678 UCPIBQDI0QM, DONE!
# 20 / 1678 UCPIBQDI0QM, DONE!
# 21 / 1678 UCPIBQDI0QM, DONE!
# 22 / 1678 UCPIBQDI0QM, DONE!
# 23 / 1678 UCPIBQDI0QM, DONE!
# 24 / 1678 UCPIBQDI0QM, DONE!
# 25 / 1678 hhSNKJ_lcNU, DONE!
# 26 / 1678 hhSNKJ_lcNU, DONE!
# 27 / 1678 hhSNKJ_lcNU, DONE!
# 28 / 1678 hhSNKJ_lcNU, DONE!
# 29 / 1678 hhSNKJ_lcNU, DONE!
# 30 / 1678 hhSNKJ_lcNU, DONE!
# 31 / 1678 hhSNKJ_lcNU, DONE!
# 32 / 1678 hhSNKJ_lcNU, DONE!
# ...
