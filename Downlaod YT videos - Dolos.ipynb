# %% [markdown]
# # General

# %%
# 1. Wipe out any existing ffmpeg python bindings
#!pip uninstall ffmpeg ffmpeg-python -y

# 2. Install ONLY the one the script needs
#!pip install ffmpeg-python

# %% [markdown]
# # Import vid Files

# %%
# Read the file, skip the first line, and save it back
with open('dolos_timestamps.csv', 'r') as f:
    lines = f.readlines()

# Check if the first line is indeed the header
if "start_time" in lines[0]:
    with open('dolos_timestamps.csv', 'w') as f:
        f.writelines(lines[1:])
    print("Header removed successfully!")
else:
    print("No header detected or already removed.")
# Out:
# No header detected or already removed.

# %%
# %%time

# Run the downloader using the timestamps file
# !python YT_video_downloader.py dolos_data_final dolos_timestamps.txt
# Out:
# Traceback (most recent call last):
#   File "/home/maria/Desktop/ΑΙ/4. ML/0. Ergasia ML/YT_video_downloader.py", line 77, in <module>
#     vidinfos = [VidInfo(x[0], x[1], x[2], x[3], out_dir) for x in lines]
#   File "/home/maria/Desktop/ΑΙ/4. ML/0. Ergasia ML/YT_video_downloader.py", line 77, in <listcomp>
#     vidinfos = [VidInfo(x[0], x[1], x[2], x[3], out_dir) for x in lines]
#   File "/home/maria/Desktop/ΑΙ/4. ML/0. Ergasia ML/YT_video_downloader.py", line 23, in __init__
#     self.start_time = to_seconds(start_time)
#   File "/home/maria/Desktop/ΑΙ/4. ML/0. Ergasia ML/YT_video_downloader.py", line 21, in to_seconds
#     return float(t)
# ValueError: could not convert string to float: 'start_time'
# CPU times: user 7.89 ms, sys: 12.7 ms, total: 20.6 ms
# Wall time: 532 ms
